# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import colormaps as cms
mpl.rc_file(f"../matplotlibrc")

# %%
l = np.array([27., 26., 27., 28., 28., 27., 27., 26., 26., 26., 25., 25.]) + 1.
x = np.arange(len(l))

p = np.polyfit(x, l, 3)
lsmooth = np.polyval(p, x)

# %%
plt.plot(x, l)
plt.plot(x, lsmooth, "--")

# %%
'[' + ', '.join([f'{lt:.3f}' for lt in lsmooth]) + ']'
# Out:
# '[27.392, 27.989, 28.333, 28.459, 28.402, 28.199, 27.885, 27.496, 27.068, 26.636, 26.236, 25.905]'
