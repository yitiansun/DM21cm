# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import colormaps as cms
mpl.rc_file(f"../matplotlibrc")

# %%
# phot
l = np.array([30., 30., 29., 28., 28., 27., 27., 27., 27., 26., 26., 26.])
x = np.arange(len(l))

p = np.polyfit(x, l, 1)
lsmooth = np.polyval(p, x)

# %%
# elec
l = np.array([27., 26., 27., 28., 28., 27., 27., 26., 26., 26., 25., 25.]) + 1.
x = np.arange(len(l))

p = np.polyfit(x, l, 3)
lsmooth = np.polyval(p, x)

# %%
plt.plot(x, l)
plt.plot(x, lsmooth, "--")

# %%
'[' + ', '.join([f'{lt:.3f}' for lt in lsmooth]) + ']'
# Out:
# '[29.679, 29.298, 28.917, 28.536, 28.155, 27.774, 27.393, 27.012, 26.631, 26.249, 25.868, 25.487]'
