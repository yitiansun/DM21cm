# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import colormaps as cms
mpl.rc_file(f"../matplotlibrc")

# %%
# phot
l = np.array([30., 30., 29., 28., 28., 27., 27., 27., 27., 26., 26., 26.])
multiplier = 1/3
x = np.arange(len(l))

p = np.polyfit(x, l, 1)
lsmooth = np.polyval(p, x)
lsmooth_adjusted = lsmooth + np.log10(multiplier)

# %%
# elec
l = np.array([27., 26., 27., 28., 28., 27., 27., 26., 26., 26., 25., 25.]) + 1.
multiplier = 4
x = np.arange(len(l))

p = np.polyfit(x, l, 3)
lsmooth = np.polyval(p, x)
lsmooth_adjusted = lsmooth + np.log10(multiplier)

# %%
plt.plot(x, l)
plt.plot(x, lsmooth, "--")
plt.plot(x, lsmooth_adjusted, "--")

# %%
'[' + ', '.join([f'{lt:.3f}' for lt in lsmooth_adjusted]) + ']'
# Out:
# '[29.202, 28.821, 28.440, 28.059, 27.678, 27.297, 26.916, 26.535, 26.153, 25.772, 25.391, 25.010]'
