# %%
# %reload_ext autoreload
# %autoreload 2

import os
import sys

import numpy as np
from astropy.io import fits

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import colormaps as cms
mpl.rc_file('../matplotlibrc')

# %%
data_dir = os.environ['DM21CM_DATA_DIR']

# %%
for k in ['hep_tf', 'lep_tf', 'lee_tf', 'cmbloss', 'lowerbound']:
    d1 = np.load(f"{data_dir}/tf/230629/phot/{k}_rxneo.npy")
    d2 = np.load(f"{data_dir}/tf/zf01/phot/{k}_rxneo.npy")
    print(k, np.allclose(d1, d2))
# Out:
# hep_tf True
# lep_tf True
# lee_tf True
# cmbloss False
# lowerbound True

# %%
k = 'cmbloss'
d1 = np.load(f"{data_dir}/tf/230629/phot/{k}_rxneo.npy")
d2 = np.load(f"{data_dir}/tf/zf01/phot/{k}_rxneo.npy")

# %%
plt.plot(d1[1,2,3])
plt.plot(d2[1,2,3])

# %%
os.listdir(f"{data_dir}/tf/zf01/phot/ionhist_outputs/")

# %%
f = fits.open(f"{data_dir}/tf/zf01/phot/ionhist_outputs/phottf_rs1_xx2_nB3.fits")
dts = np.load(f"{data_dir}/tf/zf01/phot/dt_rxneo.npy")

# %%
dts[1]
# Out:
# array([4.92414280e+14, 4.99763057e+14])

# %%
plt.plot(f[1].data['CMBLOSS'][0][0]*dts[1][0])
plt.plot(f[1].data['CMBLOSS'][0][1]*dts[1][1])
