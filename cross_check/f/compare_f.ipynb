# %%
# %reload_ext autoreload
# %autoreload 2

import os
import sys
import pickle
import logging
from tqdm import tqdm

import numpy as np
from scipy import interpolate
from astropy.io import fits
import jax.numpy as jnp

sys.path.append(os.environ['DM21CM_DIR'])
import dm21cm.physics as phys
from dm21cm.utils import load_h5_dict
from dm21cm.dm_params import DMParams
from dm21cm.evolve import get_z_edges
from dm21cm.interpolators_jax import BatchInterpolator

sys.path.append(os.environ['DH_DIR'])
import darkhistory
from darkhistory.spec.spectrum import Spectrum
from darkhistory.main import evolve as dh_evolve
from darkhistory.config import load_data as dh_load_data
print(darkhistory.__version__)

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc_file('../matplotlibrc')
# Out:
# 1.0.0-dm21cm.0

# %%
tf_name = 'zf01'
abscs = load_h5_dict(os.environ['DM21CM_DIR'] + f"/data/abscissas/abscs_{tf_name}.h5")

# %% [markdown]
# ## dm21cm_tf

# %%
dmcm_dep_tf = BatchInterpolator(f"{os.environ['DM21CM_DATA_DIR']}/tf/{tf_name}/phot_dep.h5")

# %%
# inject 1 photon
spec_N = np.zeros((500,))
i_injE = 428
spec_N[i_injE] = 1.
photeng = dmcm_dep_tf.abscs['Ein']
print(f'total energy = {np.dot(spec_N photeng)}')
# Out:
# total energy = 22435064834.560047

# %%
rs = 38.71318413405634
xe = 0.01

# %%
f_dm21cm = dmcm_dep_tf(
    in_spec = spec_N
    sum_result = False
    rs = rs
    nBs_s = jnp.array([1.006])
    x_s = jnp.array([xe]),
    out_of_bounds_action = 'clip',
) / photeng[i_injE]

f_dm21cm = np.array(f_dm21cm).flatten()
print(f_dm21cm)
# Out:
# [6.9319722e-10 1.1216477e-11 5.5977240e-10 7.8323931e-10 7.0314123e-11
#  4.6302312e-06]

# %% [markdown]
# ## DH_run

# %%
dep_tf = dh_load_data(
    'dep_tf',
    verbose=1,
    prefix="/n/holyscratch01/iaifi_lab/yitians/darkhistory/DHdata_v1_1_zf01",
    force_reload=True
)
# Out:
# ****** Loading transfer functions... ******
# Using data at /n/holyscratch01/iaifi_lab/yitians/darkhistory/DHdata_v1_1_zf01
#     for propagating photons...
#  Done!
#     for low-energy photons...  Done!
#     for low-energy electrons...  Done!
#     for high-energy deposition...  Done!
#     for total upscattered CMB energy rate...  Done!
# ****** Loading complete! ******

# %%
soln = dh_evolve(
    DM_process='swave', mDM=photeng[i_injE+1]-1e-10, sigmav=2.4e-23, primary='phot_delta', # sigmav shouldn't matter
    start_rs=rs, end_rs=rs/1.01,
    coarsen_factor=12, backreaction=True,
    struct_boost=lambda rs: 1.,
    init_cond=(xe, phys.chi*xe, 10*phys.kB),
    use_tqdm=False, verbose=1,
    cross_check_21cmfast=True,
)
# Out:
# ****** Loading transfer functions... ******
#     for inverse Compton (Thomson)...  Done!
#     for inverse Compton (relativistic)...  Done!
#     for inverse Compton (energy loss)...  Done!
# ****** Loading complete! ******
# WARNING:root:Cross checking 21cmfast!
# WARNING:root:Setting coarsen_factor=1!
# WARNING:root:Setting dlnz=0.009950330853168092!
# Loading time: 6.515 s
# Initialization time: 0.025 s
# rs =  38.71318413405634
# lowengelec_spec_at_rs.toteng()= 1.316103464964847e-11
# lowengphot_spec_at_rs.toteng()= 0.0
# x_vec_for_f =  [9.90000000e-01 8.03145695e-02 8.11258278e-04]
# rate_func_eng_unclustered(rs) =  5.271498620812896e-18
# dt =  33740796675663.348
# highengdep_at_rs =  [ 1.77941034e-25  1.41377464e-25  5.61381168e-26 -1.22797172e-27]
# compute_fs_method =  no_He
# cross_check =  False
# f_raw =  (array([2.00148786e-10, 1.12164781e-11, 1.68036238e-10, 6.27688898e-10,
#        7.37166590e-11]), array([ 4.93048433e-10,  0.00000000e+00,  3.91736159e-10,  1.55550464e-10,
#        -3.40252903e-12]))
# -----------
# rs =  38.32988528124391
# lowengelec_spec_at_rs.toteng()= 2.7608694032346773e-10
# lowengphot_spec_at_rs.toteng()= 2.0293593347365236e-08
# x_vec_for_f =  [9.91139182e-01 8.11258278e-02 5.43939893e-14]
# rate_func_eng_unclustered(rs) =  4.9659901583859186e-18
# dt =  34249289401811.23
# highengdep_at_rs =  [ 2.49176847e-24  1.91524409e-24  5.65669471e-25 -9.58419320e-27]
# compute_fs_method =  no_He
# cross_check =  False
# f_raw =  (array([5.01428021e-07, 1.85436495e-08, 2.90337737e-07, 6.34223896e-07,
#        2.69942741e-07]), array([ 7.11353184e-09,  0.00000000e+00,  5.46766283e-09,  1.61488029e-09,
#        -2.73610748e-11]))
# -----------
# Main loop time: 0.090 s

# %%
f_dh = np.array([soln['f']['low'][k] + soln['f']['high'][k] for k in soln['f']['low']])
f_dh = f_dh[:,0]

# %%
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL+1)

fig, ax = plt.subplots()

ax.plot(f_dh[:4], label='DarkHistory', color='k')
ax.plot(f_dm21cm[:4], label='dm21cm', color='r', ls=':')
ax.set_xticks(np.arange(4))
ax.set_xticklabels([s.decode('utf-8') for s in dmcm_dep_tf.abscs['out'][:4]])
ax.set(yscale='log')
#ax.set(ylim=(1e-7,1e-4))
ax.legend();

# %%
f_dm21cm[:4] / f_dh[:4]
# Out:
# array([1.        , 0.99999994, 1.        , 0.99999993])

# %% [markdown]
# ## 21 run

# %%
from dm21cm.evolve import evolve

# %%
dm_params = DMParams(
    mode = 'decay',
    primary = 'phot_delta',
    m_DM = 2*(photeng[i_injE]+0.1),
    lifetime = 1e25,
)

return_dict = evolve(
    run_name = 'dhc_test',
    z_start = 38.2,
    z_end = 4.96266792,
    zplusone_step_factor = 1.01,
    dm_params = dm_params,
    enable_elec = False,
    tf_version = 'zf01',
    
    p21c_initial_conditions = p21c.initial_conditions(
        user_params = p21c.UserParams(
            HII_DIM = 16,
            BOX_LEN = 16 * 4, # [conformal Mpc]
            N_THREADS = 32,
        ),
        cosmo_params = p21c.CosmoParams(
            OMm = Planck18.Om0,
            OMb = Planck18.Ob0,
            POWER_INDEX = Planck18.meta['n'],
            #SIGMA_8 = Planck18.meta['sigma8'],
            SIGMA_8 = 1e-8,
            hlittle = Planck18.h,
        ),
        random_seed = 54321,
        write = True,
    ),
    
    rerun_DH = False,
    clear_cache = True,
    use_tqdm = False,
    debug_flags = ['uniform_xray'],
    debug_xray_multiplier = 1.,
    debug_astro_params = p21c.AstroParams(
        L_X = 0. # log10 value
    ),
    save_dir='../run_info',
    debug_dhc_DH_xe_func=lambda z: 0.01,
    debug_dhc_delta_fixed=True,
    debug_no_bath=True,
    debug_use_tf_dt=True,
)
# Out:
# /n/home07/yitians/.conda/envs/dm21cm/lib/python3.11/site-packages/py21cmfast/inputs.py:487: UserWarning: The USE_INTERPOLATION_TABLES setting has changed in v3.1.2 to be default True. You can likely ignore this warning, but if you relied onhaving USE_INTERPOLATION_TABLES=False by *default*, please set it explicitly. To silence this warning, set it explicitly to True. Thiswarning will be removed in v4.
#   warnings.warn(
# INFO:root:Using 21cmFAST version 0.1.dev1581+g40959ca.d20230929
# INFO:root:Cache dir: /n/holyscratch01/iaifi_lab/yitians/21cmFAST-cache/dhc_test
# INFO:root:TransferFunctionWrapper: Loaded photon transfer functions.
# INFO:root:DarkHistoryWrapper: Found existing DarkHistory initial conditions.
# WARNING:root:DarkHistoryWrapper: DMParams mismatch, rerunning.
# WARNING:root:DarkHistoryWrapper: Overriding remember to turn off.
# WARNING:root:Turning off bath, remember to turn back on
# get_init_cond 9292.31412387332 0.23165742133748876
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -9.587479e-02
# zp = 3.810032e+01
# dt_dzp = -8.572903e+13
# dadia_dzp * dzp = -1.478124e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 7.661585e-03
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 0.000000e+00
# dxion_source = 0.000000e+00
# dxion_sink = 7.227056e-08
# T = 3.014094e+01
# alpha_A(T) = 1.790334e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 2.078851e-04
# f_H = 9.249617e-01
# prefactor_1 = 1.228640e-02
# curr_delNL0 = -1.830332e-06
# growth_factor_zp = 3.256493e-02
# input ionization = 0.000000e+00
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# dt 33356785139759.77 33677476183046.547
# before 9292.313 0.23165745
# input_heating 1.0119549e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.871307e-01
# zp = 3.771318e+01
# dt_dzp = -8.788830e+13
# dadia_dzp * dzp = -1.858458e+02
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -3.355266e+03
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.011955e-07
# dxion_source = 0.000000e+00
# dxion_sink = 8.851931e-03
# T = 9.292314e+03
# alpha_A(T) = 4.395140e-13
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 2.316574e-01
# f_H = 9.249617e-01
# prefactor_1 = 1.192506e-02
# curr_delNL0 = -1.812176e-06
# growth_factor_zp = 3.289120e-02
# input ionization = 8.735952e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 5751.203 0.22280549
# ----- DM21CM -----
# z 38.10031603714576
# [6.99506549e-10 1.13244685e-11 5.64812375e-10 7.90099991e-10
#  7.09473405e-11 4.67642606e-06]
# 6.9950656e-10
# 1.1324472e-11
# 5.648125e-10
# 7.901004e-10
# -----------------
# i_z=0/189 z=38.10 bath.toteng=0.000e+00 eV/Bavg
# dt 33860104410955.453 34050802162151.98
# before 5751.203 0.22280549
# input_heating 1.0142879e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.833008e-01
# zp = 3.732988e+01
# dt_dzp = -9.010197e+13
# dadia_dzp * dzp = -1.150246e+02
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -1.948101e+03
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.014288e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.132429e-02
# T = 5.751203e+03
# alpha_A(T) = 6.169715e-13
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 2.228055e-01
# f_H = 9.249617e-01
# prefactor_1 = 1.157434e-02
# curr_delNL0 = -1.794200e-06
# growth_factor_zp = 3.322074e-02
# input ionization = 8.753051e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 3688.078 0.21148115
# ----- DM21CM -----
# z 37.71318419519382
# [6.93197226e-10 1.12164778e-11 5.59772390e-10 7.83239337e-10
#  7.03141276e-11 4.63023128e-06]
# 6.9319717e-10
# 1.1216478e-11
# 5.5977234e-10
# 7.8323925e-10
# -----------------
# i_z=1/189 z=37.71 bath.toteng=0.000e+00 eV/Bavg
# dt 34370999644096.598 34751781717207.863
# before 3688.078 0.21148115
# input_heating 1.0258586e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.795013e-01
# zp = 3.695038e+01
# dt_dzp = -9.237137e+13
# dadia_dzp * dzp = -7.376107e+01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -1.155106e+03
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.025858e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.366851e-02
# T = 3.688077e+03
# alpha_A(T) = 8.390176e-13
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 2.114812e-01
# f_H = 9.249617e-01
# prefactor_1 = 1.123394e-02
# curr_delNL0 = -1.776402e-06
# growth_factor_zp = 3.355357e-02
# input ionization = 8.850176e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 2459.2104 0.19781272
# ----- DM21CM -----
# z 37.329885341776055
# [6.86755193e-10 1.11083037e-11 5.54613636e-10 7.76194962e-10
#  6.96644004e-11 4.58439623e-06]
# 6.8675526e-10
# 1.11083035e-11
# 5.546136e-10
# 7.76195e-10
# -----------------
# i_z=2/189 z=37.33 bath.toteng=0.000e+00 eV/Bavg
# dt 34889584761256.23 35445820932957.69
# before 2459.2104 0.19781272
# input_heating 1.0369442e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.757477e-01
# zp = 3.657463e+01
# dt_dzp = -9.469796e+13
# dadia_dzp * dzp = -4.918438e+01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -7.003855e+02
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.036944e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.551799e-02
# T = 2.459210e+03
# alpha_A(T) = 1.105092e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.978127e-01
# f_H = 9.249617e-01
# prefactor_1 = 1.090355e-02
# curr_delNL0 = -1.758782e-06
# growth_factor_zp = 3.388973e-02
# input ionization = 8.943037e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 1709.6405 0.18229468
# ----- DM21CM -----
# z 36.950381526510945
# [6.80376964e-10 1.10012009e-11 5.49505978e-10 7.69220471e-10
#  6.90211078e-11 4.53901560e-06]
# 6.8037703e-10
# 1.1001204e-11
# 5.4950616e-10
# 7.692206e-10
# -----------------
# i_z=3/189 z=36.95 bath.toteng=0.000e+00 eV/Bavg
# dt 35415975395993.266 36132988473304.055
# before 1709.6405 0.18229468
# input_heating 1.0475572e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.720245e-01
# zp = 3.620261e+01
# dt_dzp = -9.708312e+13
# dadia_dzp * dzp = -3.419266e+01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -4.349316e+02
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.047557e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.656244e-02
# T = 1.709640e+03
# alpha_A(T) = 1.409721e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.822947e-01
# f_H = 9.249617e-01
# prefactor_1 = 1.058288e-02
# curr_delNL0 = -1.741336e-06
# growth_factor_zp = 3.422925e-02
# input ionization = 9.031744e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 1240.5159 0.1657323
# ----- DM21CM -----
# z 36.57463517476331
# [6.74061903e-10 1.08951583e-11 5.44448905e-10 7.62314928e-10
#  6.83841861e-11 4.49408385e-06]
# 6.7406186e-10
# 1.0895156e-11
# 5.44449e-10
# 7.623148e-10
# -----------------
# i_z=4/189 z=36.57 bath.toteng=0.000e+00 eV/Bavg
# dt 35950288919004.5 36813352374637.086
# before 1240.5159 0.1657323
# input_heating 1.0577102e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.683434e-01
# zp = 3.583427e+01
# dt_dzp = -9.952837e+13
# dadia_dzp * dzp = -2.481037e+01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -2.770919e+02
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.057710e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.667446e-02
# T = 1.240516e+03
# alpha_A(T) = 1.742907e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.657323e-01
# f_H = 9.249617e-01
# prefactor_1 = 1.027164e-02
# curr_delNL0 = -1.724064e-06
# growth_factor_zp = 3.457217e-02
# input ionization = 9.116398e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 938.614 0.14905784
# ----- DM21CM -----
# z 36.20260908392407
# [6.67809413e-10 1.07901670e-11 5.39441948e-10 7.55477909e-10
#  6.77535769e-11 4.44959713e-06]
# 6.678096e-10
# 1.0790171e-11
# 5.3944216e-10
# 7.5547796e-10
# -----------------
# i_z=5/189 z=36.20 bath.toteng=0.000e+00 eV/Bavg
# dt 36492644464163.39 37486979999719.3
# before 938.614 0.14905784
# input_heating 1.0674136e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.646965e-01
# zp = 3.546957e+01
# dt_dzp = -1.020352e+14
# dadia_dzp * dzp = -1.877232e+01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -1.813740e+02
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.067413e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.595004e-02
# T = 9.386138e+02
# alpha_A(T) = 2.092046e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.490578e-01
# f_H = 9.249617e-01
# prefactor_1 = 9.969553e-03
# curr_delNL0 = -1.706964e-06
# growth_factor_zp = 3.491851e-02
# input ionization = 9.197103e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 738.46765 0.13310777
# ----- DM21CM -----
# z 35.834266419726795
# [6.61618731e-10 1.06862132e-11 5.34484472e-10 7.48708392e-10
#  6.71292004e-11 4.40555056e-06]
# 6.6161876e-10
# 1.0686214e-11
# 5.344846e-10
# 7.4870843e-10
# -----------------
# i_z=6/189 z=35.83 bath.toteng=0.000e+00 eV/Bavg
# dt 37043162954930.58 38153938044355.15
# before 738.46765 0.13310777
# input_heating 1.0766792e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.610840e-01
# zp = 3.510849e+01
# dt_dzp = -1.046052e+14
# dadia_dzp * dzp = -1.476931e+01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -1.220856e+02
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.076679e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.464193e-02
# T = 7.384675e+02
# alpha_A(T) = 2.444526e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.331078e-01
# f_H = 9.249617e-01
# prefactor_1 = 9.676351e-03
# curr_delNL0 = -1.690034e-06
# growth_factor_zp = 3.526832e-02
# input ionization = 9.273962e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 601.6127 0.11846587
# ----- DM21CM -----
# z 35.469570712600785
# [6.55489346e-10 1.05832895e-11 5.29576134e-10 7.42006039e-10
#  6.65110089e-11 4.36194068e-06]
# 6.554893e-10
# 1.0583287e-11
# 5.295761e-10
# 7.420059e-10
# -----------------
# i_z=7/189 z=35.47 bath.toteng=0.000e+00 eV/Bavg
# dt 37601967131179.195 38814292543994.6
# before 601.6127 0.11846587
# input_heating 1.0855181e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.575096e-01
# zp = 3.475098e+01
# dt_dzp = -1.072399e+14
# dadia_dzp * dzp = -1.203225e+01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -8.451148e+01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.085518e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.304051e-02
# T = 6.016127e+02
# alpha_A(T) = 2.789928e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.184658e-01
# f_H = 9.249617e-01
# prefactor_1 = 9.391771e-03
# curr_delNL0 = -1.673271e-06
# growth_factor_zp = 3.562163e-02
# input ionization = 9.347071e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 505.06888 0.10542535
# ----- DM21CM -----
# z 35.108485854060184
# [6.49420789e-10 1.04813861e-11 5.24716426e-10 7.35369998e-10
#  6.58989439e-11 4.31876224e-06]
# 6.4942085e-10
# 1.0481384e-11
# 5.247163e-10
# 7.3537e-10
# -----------------
# i_z=8/189 z=35.11 bath.toteng=0.000e+00 eV/Bavg
# dt 38169181576405.1 39468108880271.28
# before 505.06888 0.10542535
# input_heating 1.0939413e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.539696e-01
# zp = 3.439701e+01
# dt_dzp = -1.099409e+14
# dadia_dzp * dzp = -1.010136e+01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -6.011063e+01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.093941e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.138221e-02
# T = 5.050689e+02
# alpha_A(T) = 3.121074e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.054253e-01
# f_H = 9.249617e-01
# prefactor_1 = 9.115561e-03
# curr_delNL0 = -1.656676e-06
# growth_factor_zp = 3.597846e-02
# input ionization = 9.416526e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 434.85693 0.09404313
# ----- DM21CM -----
# z 34.7509760931289
# [6.43412170e-10 1.03804902e-11 5.19904753e-10 7.28799675e-10
#  6.52929310e-11 4.27601109e-06]
# 6.4341227e-10
# 1.038049e-11
# 5.199048e-10
# 7.287998e-10
# -----------------
# i_z=9/189 z=34.75 bath.toteng=0.000e+00 eV/Bavg
# dt 38744932745337.45 40115451787475.92
# before 434.85693 0.09404313
# input_heating 1.1019586e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.504677e-01
# zp = 3.404654e+01
# dt_dzp = -1.127100e+14
# dadia_dzp * dzp = -8.697196e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -4.386148e+01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.101959e-07
# dxion_source = 0.000000e+00
# dxion_sink = 9.817541e-03
# T = 4.348569e+02
# alpha_A(T) = 3.433959e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 9.404313e-02
# f_H = 9.249617e-01
# prefactor_1 = 8.847472e-03
# curr_delNL0 = -1.640245e-06
# growth_factor_zp = 3.633887e-02
# input ionization = 9.482419e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 382.2983 0.08422557
# ----- DM21CM -----
# z 34.39700603280089
# [6.37463062e-10 1.02805932e-11 5.15140731e-10 7.22294304e-10
#  6.46929171e-11 4.23368337e-06]
# 6.3746325e-10
# 1.0280596e-11
# 5.151409e-10
# 7.2229434e-10
# -----------------
# i_z=10/189 z=34.40 bath.toteng=0.000e+00 eV/Bavg
# dt 39329348991976.195 40756385358965.67
# before 382.2983 0.08422557
# input_heating 1.10958155e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.469925e-01
# zp = 3.369955e+01
# dt_dzp = -1.155488e+14
# dadia_dzp * dzp = -7.645900e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -3.276419e+01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.109582e-07
# dxion_source = 0.000000e+00
# dxion_sink = 8.420165e-03
# T = 3.822982e+02
# alpha_A(T) = 3.727074e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 8.422559e-02
# f_H = 9.249617e-01
# prefactor_1 = 8.587271e-03
# curr_delNL0 = -1.623977e-06
# growth_factor_zp = 3.670288e-02
# input ionization = 9.544848e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 341.88815 0.075805426
# ----- DM21CM -----
# z 34.04654062653553
# [6.31572870e-10 1.01816859e-11 5.10423893e-10 7.15853461e-10
#  6.40988490e-11 4.19177458e-06]
# 6.31573e-10
# 1.0181685e-11
# 5.10424e-10
# 7.158534e-10
# -----------------
# i_z=11/189 z=34.05 bath.toteng=0.000e+00 eV/Bavg
# dt 39922560598035.63 41390973053509.98
# before 341.88815 0.075805426
# input_heating 1.1168198e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.435631e-01
# zp = 3.335598e+01
# dt_dzp = -1.184592e+14
# dadia_dzp * dzp = -6.837828e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -2.500003e+01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.116820e-07
# dxion_source = 0.000000e+00
# dxion_sink = 7.212931e-03
# T = 3.418882e+02
# alpha_A(T) = 4.000565e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 7.580543e-02
# f_H = 9.249617e-01
# prefactor_1 = 8.334718e-03
# curr_delNL0 = -1.607871e-06
# growth_factor_zp = 3.707053e-02
# input ionization = 9.603896e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 310.0503 0.068592496
# ----- DM21CM -----
# z 33.69954517478765
# [6.25741084e-10 1.00837577e-11 5.05753814e-10 7.09476465e-10
#  6.35106683e-11 4.15028156e-06]
# 6.25741e-10
# 1.00837585e-11
# 5.0575377e-10
# 7.094763e-10
# -----------------
# i_z=12/189 z=33.70 bath.toteng=0.000e+00 eV/Bavg
# dt 40524699801802.195 42019277701573.65
# before 310.0503 0.068592496
# input_heating 1.1236827e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.401566e-01
# zp = 3.301583e+01
# dt_dzp = -1.214428e+14
# dadia_dzp * dzp = -6.200975e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -1.943959e+01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.123683e-07
# dxion_source = 0.000000e+00
# dxion_sink = 6.188879e-03
# T = 3.100503e+02
# alpha_A(T) = 4.255568e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 6.859250e-02
# f_H = 9.249617e-01
# prefactor_1 = 8.089597e-03
# curr_delNL0 = -1.591925e-06
# growth_factor_zp = 3.744186e-02
# input ionization = 9.659653e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 284.4097 0.06240362
# ----- DM21CM -----
# z 33.35598532157193
# [6.19966897e-10 9.98679845e-12 5.01129899e-10 7.03162382e-10
#  6.29283006e-11 4.10919841e-06]
# 6.19967e-10
# 9.986799e-12
# 5.011299e-10
# 7.0316236e-10
# -----------------
# i_z=13/189 z=33.36 bath.toteng=0.000e+00 eV/Bavg
# dt 41135900827445.58 42641361511537.67
# before 284.4097 0.06240362
# input_heating 1.1301805e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.367920e-01
# zp = 3.267904e+01
# dt_dzp = -1.245016e+14
# dadia_dzp * dzp = -5.688222e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -1.537211e+01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.130181e-07
# dxion_source = 0.000000e+00
# dxion_sink = 5.328979e-03
# T = 2.844097e+02
# alpha_A(T) = 4.493672e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 6.240362e-02
# f_H = 9.249617e-01
# prefactor_1 = 7.851682e-03
# curr_delNL0 = -1.576138e-06
# growth_factor_zp = 3.781690e-02
# input ionization = 9.712207e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 263.3494 0.05707465
# ----- DM21CM -----
# z 33.015827051061315
# [6.14249926e-10 9.89079965e-12 4.96551765e-10 6.96910955e-10
#  6.23517034e-11 4.06852234e-06]
# 6.1425004e-10
# 9.890799e-12
# 4.9655174e-10
# 6.969111e-10
# -----------------
# i_z=14/189 z=33.02 bath.toteng=0.000e+00 eV/Bavg
# dt 41756299914728.77 43257286075858.49
# before 263.3494 0.05707465
# input_heating 1.13632275e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.334541e-01
# zp = 3.234558e+01
# dt_dzp = -1.276374e+14
# dadia_dzp * dzp = -5.266962e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -1.233689e+01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.136323e-07
# dxion_source = 0.000000e+00
# dxion_sink = 4.609520e-03
# T = 2.633494e+02
# alpha_A(T) = 4.716643e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 5.707464e-02
# f_H = 9.249617e-01
# prefactor_1 = 7.620766e-03
# curr_delNL0 = -1.560507e-06
# growth_factor_zp = 3.819569e-02
# input ionization = 9.761641e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 245.74559 0.052465126
# ----- DM21CM -----
# z 32.67903668421912
# [6.08589576e-10 9.79575130e-12 4.92018988e-10 6.90721378e-10
#  6.17808182e-11 4.02824882e-06]
# 6.085895e-10
# 9.795749e-12
# 4.9201904e-10
# 6.907215e-10
# -----------------
# i_z=15/189 z=32.68 bath.toteng=0.000e+00 eV/Bavg
# dt 42386035349203.43 43867112377166.23
# before 245.74559 0.052465126
# input_heating 1.14211836e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.301544e-01
# zp = 3.201543e+01
# dt_dzp = -1.308522e+14
# dadia_dzp * dzp = -4.914913e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -1.003139e+01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.142118e-07
# dxion_source = 0.000000e+00
# dxion_sink = 4.007846e-03
# T = 2.457455e+02
# alpha_A(T) = 4.926216e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 5.246512e-02
# f_H = 9.249617e-01
# prefactor_1 = 7.396641e-03
# curr_delNL0 = -1.545032e-06
# growth_factor_zp = 3.857826e-02
# input ionization = 9.808035e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 230.79927 0.04845727
# ----- DM21CM -----
# z 32.34558087546448
# [6.02985295e-10 9.70164478e-12 4.87531099e-10 6.84593140e-10
#  6.12155760e-11 3.98837437e-06]
# 6.0298516e-10
# 9.701643e-12
# 4.87531e-10
# 6.8459305e-10
# -----------------
# i_z=16/189 z=32.35 bath.toteng=0.000e+00 eV/Bavg
# dt 43025247492806.28 44470900794302.6
# before 230.79927 0.04845727
# input_heating 1.1475765e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.268852e-01
# zp = 3.168854e+01
# dt_dzp = -1.341479e+14
# dadia_dzp * dzp = -4.615982e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -8.251246e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.147576e-07
# dxion_source = 0.000000e+00
# dxion_sink = 3.503502e-03
# T = 2.307992e+02
# alpha_A(T) = 5.124024e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 4.845727e-02
# f_H = 9.249617e-01
# prefactor_1 = 7.179107e-03
# curr_delNL0 = -1.529710e-06
# growth_factor_zp = 3.896467e-02
# input ionization = 9.851472e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 217.93204 0.044953767
# ----- DM21CM -----
# z 32.01542660937077
# [5.97436486e-10 9.60846879e-12 4.83087632e-10 6.78525519e-10
#  6.06559448e-11 3.94889446e-06]
# 5.974366e-10
# 9.60847e-12
# 4.8308774e-10
# 6.785256e-10
# -----------------
# i_z=17/189 z=32.02 bath.toteng=0.000e+00 eV/Bavg
# dt 43674078814942.65 45068711108299.016
# before 217.93204 0.044953767
# input_heating 1.1527061e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.236485e-01
# zp = 3.136489e+01
# dt_dzp = -1.375267e+14
# dadia_dzp * dzp = -4.358634e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -6.856455e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.152706e-07
# dxion_source = 0.000000e+00
# dxion_sink = 3.079238e-03
# T = 2.179320e+02
# alpha_A(T) = 5.311541e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 4.495377e-02
# f_H = 9.249617e-01
# prefactor_1 = 6.967969e-03
# curr_delNL0 = -1.514541e-06
# growth_factor_zp = 3.935493e-02
# input ionization = 9.892029e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 206.71689 0.04187453
# ----- DM21CM -----
# z 31.688541197396802
# [5.91942599e-10 9.51621602e-12 4.78688160e-10 6.72518005e-10
#  6.01018398e-11 3.90980595e-06]
# 5.9194266e-10
# 9.516215e-12
# 4.786882e-10
# 6.7251793e-10
# -----------------
# i_z=18/189 z=31.69 bath.toteng=0.000e+00 eV/Bavg
# dt 44332673924021.9 45660602508295.45
# before 206.71689 0.04187453
# input_heating 1.1575153e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.204460e-01
# zp = 3.104445e+01
# dt_dzp = -1.409905e+14
# dadia_dzp * dzp = -4.134358e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -5.749039e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.157516e-07
# dxion_source = 0.000000e+00
# dxion_sink = 2.720755e-03
# T = 2.067169e+02
# alpha_A(T) = 5.490082e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 4.187453e-02
# f_H = 9.249617e-01
# prefactor_1 = 6.763044e-03
# curr_delNL0 = -1.499522e-06
# growth_factor_zp = 3.974910e-02
# input ionization = 9.929783e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 196.83351 0.039153777
# ----- DM21CM -----
# z 31.364892274650302
# [5.86503079e-10 9.42487652e-12 4.74332217e-10 6.66569959e-10
#  5.95532289e-11 3.87110363e-06]
# 5.86503e-10
# 9.424873e-12
# 4.743322e-10
# 6.665698e-10
# -----------------
# i_z=19/189 z=31.36 bath.toteng=0.000e+00 eV/Bavg
# dt 45001179599444.82 46246633597400.85
# before 196.83351 0.039153777
# input_heating 1.1620137e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.172703e-01
# zp = 3.072718e+01
# dt_dzp = -1.445416e+14
# dadia_dzp * dzp = -3.936652e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -4.859077e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.162014e-07
# dxion_source = 0.000000e+00
# dxion_sink = 2.416294e-03
# T = 1.968335e+02
# alpha_A(T) = 5.660808e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.915378e-02
# f_H = 9.249617e-01
# prefactor_1 = 6.564143e-03
# curr_delNL0 = -1.484652e-06
# growth_factor_zp = 4.014721e-02
# input ionization = 9.964809e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 188.03783 0.036737483
# ----- DM21CM -----
# z 31.044447796683464
# [5.81117502e-10 9.33444231e-12 4.70019462e-10 6.60680873e-10
#  5.90100484e-11 3.83278541e-06]
# 5.8111743e-10
# 9.33444e-12
# 4.7001947e-10
# 6.606808e-10
# -----------------
# i_z=20/189 z=31.04 bath.toteng=0.000e+00 eV/Bavg
# dt 45679744824090.32 46826862398495.3
# before 188.03783 0.036737483
# input_heating 1.1662089e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.141308e-01
# zp = 3.041305e+01
# dt_dzp = -1.481822e+14
# dadia_dzp * dzp = -3.760760e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -4.136225e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.166209e-07
# dxion_source = 0.000000e+00
# dxion_sink = 2.156446e-03
# T = 1.880378e+02
# alpha_A(T) = 5.824728e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.673748e-02
# f_H = 9.249617e-01
# prefactor_1 = 6.371093e-03
# curr_delNL0 = -1.469930e-06
# growth_factor_zp = 4.054930e-02
# input ionization = 9.997183e-13
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 180.14084 0.03458104
# ----- DM21CM -----
# z 30.727176036320262
# [5.75785188e-10 9.24490210e-12 4.65749386e-10 6.54849980e-10
#  5.84722453e-11 3.79484570e-06]
# 5.7578525e-10
# 9.244902e-12
# 4.657495e-10
# 6.5485e-10
# -----------------
# i_z=21/189 z=30.73 bath.toteng=0.000e+00 eV/Bavg
# dt 46368520817259.28 47401346359974.945
# before 180.14084 0.03458104
# input_heating 1.1701092e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.110199e-01
# zp = 3.010203e+01
# dt_dzp = -1.519144e+14
# dadia_dzp * dzp = -3.602812e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -3.543230e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.170109e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.933464e-03
# T = 1.801408e+02
# alpha_A(T) = 5.982732e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.458104e-02
# f_H = 9.249617e-01
# prefactor_1 = 6.183720e-03
# curr_delNL0 = -1.455355e-06
# growth_factor_zp = 4.095541e-02
# input ionization = 1.002697e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 172.9948 0.032647576
# ----- DM21CM -----
# z 30.41304558051511
# [5.70505669e-10 9.15624858e-12 4.61521562e-10 6.49076856e-10
#  5.79397662e-11 3.75728243e-06]
# 5.7050564e-10
# 9.156248e-12
# 4.6152157e-10
# 6.4907685e-10
# -----------------
# i_z=22/189 z=30.41 bath.toteng=0.000e+00 eV/Bavg
# dt 47067661068119.49 47970142361439.945
# before 172.9948 0.032647576
# input_heating 1.1737214e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.079414e-01
# zp = 2.979408e+01
# dt_dzp = -1.557406e+14
# dadia_dzp * dzp = -3.459902e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -3.052471e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.173722e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.741155e-03
# T = 1.729948e+02
# alpha_A(T) = 6.135588e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.264758e-02
# f_H = 9.249617e-01
# prefactor_1 = 6.001857e-03
# curr_delNL0 = -1.440924e-06
# growth_factor_zp = 4.136558e-02
# input ionization = 1.005425e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 166.4824 0.030906416
# ----- DM21CM -----
# z 30.102025327242682
# [5.65278435e-10 9.06847312e-12 4.57335609e-10 6.43360905e-10
#  5.74125635e-11 3.72009037e-06]
# 5.652783e-10
# 9.06847e-12
# 4.5733556e-10
# 6.433608e-10
# -----------------
# i_z=23/189 z=30.10 bath.toteng=0.000e+00 eV/Bavg
# dt 47777321369641.49 48533306719326.086
# before 166.4824 0.030906416
# input_heating 1.1770555e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.048916e-01
# zp = 2.948919e+01
# dt_dzp = -1.596632e+14
# dadia_dzp * dzp = -3.329644e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -2.643003e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.177055e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.574444e-03
# T = 1.664824e+02
# alpha_A(T) = 6.283973e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.090642e-02
# f_H = 9.249617e-01
# prefactor_1 = 5.825344e-03
# curr_delNL0 = -1.426636e-06
# growth_factor_zp = 4.177985e-02
# input ionization = 1.007908e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 160.50975 0.02933198
# ----- DM21CM -----
# z 29.794084482418498
# [5.60102976e-10 8.98156709e-12 4.53191144e-10 6.37701533e-10
#  5.68905787e-11 3.68326674e-06]
# 5.601031e-10
# 8.981567e-12
# 4.5319112e-10
# 6.377016e-10
# -----------------
# i_z=24/189 z=29.79 bath.toteng=0.000e+00 eV/Bavg
# dt 48497659853030.15 49090895192480.68
# before 160.50975 0.02933198
# input_heating 1.18011684e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -3.018742e-01
# zp = 2.918732e+01
# dt_dzp = -1.636846e+14
# dadia_dzp * dzp = -3.210205e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -2.298881e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.180117e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.429241e-03
# T = 1.605098e+02
# alpha_A(T) = 6.428475e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 2.933198e-02
# f_H = 9.249617e-01
# prefactor_1 = 5.654021e-03
# curr_delNL0 = -1.412491e-06
# growth_factor_zp = 4.219826e-02
# input ionization = 1.010154e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 155.0007 0.02790273
# ----- DM21CM -----
# z 29.489192556849996
# [5.54978739e-10 8.89552119e-12 4.49087657e-10 6.32098186e-10
#  5.63737587e-11 3.64680805e-06]
# 5.549787e-10
# 8.895523e-12
# 4.4908774e-10
# 6.320982e-10
# -----------------
# i_z=25/189 z=29.49 bath.toteng=0.000e+00 eV/Bavg
# dt 49228837022670.0 49642962987683.25
# before 155.0007 0.02790273
# input_heating 1.1829139e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.988834e-01
# zp = 2.888844e+01
# dt_dzp = -1.678072e+14
# dadia_dzp * dzp = -3.100004e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -2.007699e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.182914e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.302155e-03
# T = 1.550007e+02
# alpha_A(T) = 6.569611e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 2.790274e-02
# f_H = 9.249617e-01
# prefactor_1 = 5.487737e-03
# curr_delNL0 = -1.398485e-06
# growth_factor_zp = 4.262086e-02
# input ionization = 1.012169e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 149.89297 0.026600577
# ----- DM21CM -----
# z 29.187319363217817
# [5.49905215e-10 8.81032678e-12 4.45024808e-10 6.26550355e-10
#  5.58620555e-11 3.61071012e-06]
# 5.4990523e-10
# 8.810327e-12
# 4.4502477e-10
# 6.265502e-10
# -----------------
# i_z=26/189 z=29.19 bath.toteng=0.000e+00 eV/Bavg
# dt 49971015791593.04 50330144852069.48
# before 149.89297 0.026600577
# input_heating 1.1886701e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.959251e-01
# zp = 2.859251e+01
# dt_dzp = -1.720337e+14
# dadia_dzp * dzp = -2.997860e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -1.759845e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.188670e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.190454e-03
# T = 1.498930e+02
# alpha_A(T) = 6.707834e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 2.660058e-02
# f_H = 9.249617e-01
# prefactor_1 = 5.326344e-03
# curr_delNL0 = -1.384619e-06
# growth_factor_zp = 4.304768e-02
# input ionization = 1.016723e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 145.13527 0.025410123
# ----- DM21CM -----
# z 28.888435013086948
# [5.44841255e-10 8.72569228e-12 4.40966720e-10 6.21002950e-10
#  5.53508413e-11 3.57495415e-06]
# 5.448412e-10
# 8.725695e-12
# 4.409668e-10
# 6.21003e-10
# -----------------
# i_z=27/189 z=28.89 bath.toteng=0.000e+00 eV/Bavg
# dt 50724361517449.28 51356324090193.15
# before 145.13527 0.025410123
# input_heating 1.2019167e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.929955e-01
# zp = 2.829951e+01
# dt_dzp = -1.763666e+14
# dadia_dzp * dzp = -2.902708e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -1.547670e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.201917e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.091845e-03
# T = 1.451353e+02
# alpha_A(T) = 6.843545e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 2.541013e-02
# f_H = 9.249617e-01
# prefactor_1 = 5.169697e-03
# curr_delNL0 = -1.370891e-06
# growth_factor_zp = 4.347877e-02
# input ionization = 1.027711e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 140.6849 0.02431828
# ----- DM21CM -----
# z 28.592509913947474
# [5.39727433e-10 8.64119593e-12 4.36861448e-10 6.15376479e-10
#  5.48334261e-11 3.53951333e-06]
# 5.3972743e-10
# 8.641196e-12
# 4.3686135e-10
# 6.1537647e-10
# -----------------
# i_z=28/189 z=28.59 bath.toteng=0.000e+00 eV/Bavg
# dt 51489042039024.73 52372343137840.36
# before 140.6849 0.02431828
# input_heating 1.2145993e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.900944e-01
# zp = 2.800942e+01
# dt_dzp = -1.808086e+14
# dadia_dzp * dzp = -2.813700e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -1.365112e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.214599e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.004440e-03
# T = 1.406849e+02
# alpha_A(T) = 6.977099e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 2.431828e-02
# f_H = 9.249617e-01
# prefactor_1 = 5.017656e-03
# curr_delNL0 = -1.357299e-06
# growth_factor_zp = 4.391417e-02
# input ionization = 1.038206e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 136.50609 0.023313846
# ----- DM21CM -----
# z 28.299514766284627
# [5.34664239e-10 8.55753713e-12 4.32796813e-10 6.09805694e-10
#  5.43211331e-11 3.50442386e-06]
# 5.346642e-10
# 8.557538e-12
# 4.3279688e-10
# 6.0980554e-10
# -----------------
# i_z=29/189 z=28.30 bath.toteng=0.000e+00 eV/Bavg
# dt 52265227713299.41 53378302590956.39
# before 136.50609 0.023313846
# input_heating 1.2267321e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.872219e-01
# zp = 2.772220e+01
# dt_dzp = -1.853626e+14
# dadia_dzp * dzp = -2.730121e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -1.207299e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.226732e-07
# dxion_source = 0.000000e+00
# dxion_sink = 9.266690e-04
# T = 1.365061e+02
# alpha_A(T) = 7.108808e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 2.331384e-02
# f_H = 9.249617e-01
# prefactor_1 = 4.870088e-03
# curr_delNL0 = -1.343842e-06
# growth_factor_zp = 4.435392e-02
# input ionization = 1.048221e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 132.56863 0.022387175
# ----- DM21CM -----
# z 28.00942056067785
# [5.29651119e-10 8.47470591e-12 4.28772476e-10 6.04290127e-10
#  5.38139093e-11 3.46968158e-06]
# 5.296512e-10
# 8.474708e-12
# 4.2877252e-10
# 6.042903e-10
# -----------------
# i_z=30/189 z=28.01 bath.toteng=0.000e+00 eV/Bavg
# dt 53053091453026.47 54374302049487.14
# before 132.56863 0.022387175
# input_heating 1.2383292e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.843781e-01
# zp = 2.743782e+01
# dt_dzp = -1.900312e+14
# dadia_dzp * dzp = -2.651372e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -1.070290e+00
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.238329e-07
# dxion_source = 0.000000e+00
# dxion_sink = 8.572186e-04
# T = 1.325686e+02
# alpha_A(T) = 7.238953e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 2.238717e-02
# f_H = 9.249617e-01
# prefactor_1 = 4.726859e-03
# curr_delNL0 = -1.330518e-06
# growth_factor_zp = 4.479807e-02
# input ionization = 1.057769e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 128.84695 0.021529952
# ----- DM21CM -----
# z 27.722198574928562
# [5.24687691e-10 8.39269629e-12 4.24787927e-10 5.98829140e-10
#  5.33117174e-11 3.43528335e-06]
# 5.2468774e-10
# 8.392697e-12
# 4.24788e-10
# 5.9882926e-10
# -----------------
# i_z=31/189 z=27.72 bath.toteng=0.000e+00 eV/Bavg
# dt 53852808764897.8 55360440127240.34
# before 128.84695 0.021529952
# input_heating 1.2494039e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.815628e-01
# zp = 2.715626e+01
# dt_dzp = -1.948173e+14
# dadia_dzp * dzp = -2.576942e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -9.508717e-01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.249404e-07
# dxion_source = 0.000000e+00
# dxion_sink = 7.949836e-04
# T = 1.288470e+02
# alpha_A(T) = 7.367782e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 2.152995e-02
# f_H = 9.249617e-01
# prefactor_1 = 4.587843e-03
# curr_delNL0 = -1.317327e-06
# growth_factor_zp = 4.524666e-02
# input ionization = 1.066861e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 125.31918 0.020734968
# ----- DM21CM -----
# z 27.437820371216397
# [5.19773402e-10 8.31149765e-12 4.20842911e-10 5.93422224e-10
#  5.28144883e-11 3.40122568e-06]
# 5.1977334e-10
# 8.3114965e-12
# 4.2084278e-10
# 5.934222e-10
# -----------------
# i_z=32/189 z=27.44 bath.toteng=0.000e+00 eV/Bavg
# dt 54664557788242.51 56336814461649.45
# before 125.31918 0.020734968
# input_heating 1.2599693e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.787743e-01
# zp = 2.687748e+01
# dt_dzp = -1.997241e+14
# dadia_dzp * dzp = -2.506378e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -8.464005e-01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.259969e-07
# dxion_source = 0.000000e+00
# dxion_sink = 7.390263e-04
# T = 1.253192e+02
# alpha_A(T) = 7.495521e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 2.073497e-02
# f_H = 9.249617e-01
# prefactor_1 = 4.452916e-03
# curr_delNL0 = -1.304267e-06
# growth_factor_zp = 4.569973e-02
# input ionization = 1.075508e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 121.96641 0.019995939
# ----- DM21CM -----
# z 27.15625779328356
# [5.14907743e-10 8.23110202e-12 4.16936875e-10 5.88068783e-10
#  5.23221795e-11 3.36750475e-06]
# 5.149079e-10
# 8.231103e-12
# 4.1693687e-10
# 5.8806876e-10
# -----------------
# i_z=33/189 z=27.16 bath.toteng=0.000e+00 eV/Bavg
# dt 55488519334310.625 57303521723440.664
# before 121.96641 0.019995939
# input_heating 1.2700387e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.760143e-01
# zp = 2.660147e+01
# dt_dzp = -2.047543e+14
# dadia_dzp * dzp = -2.439325e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -7.547044e-01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.270039e-07
# dxion_source = 0.000000e+00
# dxion_sink = 6.885613e-04
# T = 1.219664e+02
# alpha_A(T) = 7.622370e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.999594e-02
# f_H = 9.249617e-01
# prefactor_1 = 4.321956e-03
# curr_delNL0 = -1.291336e-06
# growth_factor_zp = 4.615734e-02
# input ionization = 1.083723e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 118.77235 0.019307379
# ----- DM21CM -----
# z 26.87748296364709
# [5.10090288e-10 8.15150275e-12 4.13069563e-10 5.82768435e-10
#  5.18347486e-11 3.33411812e-06]
# 5.1009047e-10
# 8.151504e-12
# 4.1306972e-10
# 5.827685e-10
# -----------------
# i_z=34/189 z=26.88 bath.toteng=0.000e+00 eV/Bavg
# dt 56324876926122.57 58260657626204.234
# before 118.77235 0.019307379
# input_heating 1.2796237e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.732830e-01
# zp = 2.632819e+01
# dt_dzp = -2.099113e+14
# dadia_dzp * dzp = -2.375457e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -6.739713e-01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.279624e-07
# dxion_source = 0.000000e+00
# dxion_sink = 6.429148e-04
# T = 1.187724e+02
# alpha_A(T) = 7.748511e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.930738e-02
# f_H = 9.249617e-01
# prefactor_1 = 4.194848e-03
# curr_delNL0 = -1.278534e-06
# growth_factor_zp = 4.661952e-02
# input ionization = 1.091515e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 115.72291 0.018664468
# ----- DM21CM -----
# z 26.601468280838702
# [5.05320528e-10 8.07269254e-12 4.09240509e-10 5.77520543e-10
#  5.13521529e-11 3.30106231e-06]
# 5.0532056e-10
# 8.072691e-12
# 4.0924042e-10
# 5.775205e-10
# -----------------
# i_z=35/189 z=26.60 bath.toteng=0.000e+00 eV/Bavg
# dt 57173816838911.164 59208316935871.125
# before 115.72291 0.018664468
# input_heating 1.2887378e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.705765e-01
# zp = 2.605761e+01
# dt_dzp = -2.151982e+14
# dadia_dzp * dzp = -2.314462e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -6.026785e-01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.288738e-07
# dxion_source = 0.000000e+00
# dxion_sink = 6.015021e-04
# T = 1.157229e+02
# alpha_A(T) = 7.874111e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.866447e-02
# f_H = 9.249617e-01
# prefactor_1 = 4.071478e-03
# curr_delNL0 = -1.265859e-06
# growth_factor_zp = 4.708632e-02
# input ionization = 1.098897e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 112.80579 0.018062964
# ----- DM21CM -----
# z 26.328186416671983
# [5.00597951e-10 7.99466209e-12 4.05449372e-10 5.72324510e-10
#  5.08743235e-11 3.26833348e-06]
# 5.005978e-10
# 7.9946605e-12
# 4.0544934e-10
# 5.723244e-10
# -----------------
# i_z=36/189 z=26.33 bath.toteng=0.000e+00 eV/Bavg
# dt 58035528141150.94 60146593480095.77
# before 112.80579 0.018062964
# input_heating 1.2973929e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.678967e-01
# zp = 2.578971e+01
# dt_dzp = -2.206182e+14
# dadia_dzp * dzp = -2.256112e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -5.395607e-01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.297393e-07
# dxion_source = 0.000000e+00
# dxion_sink = 5.638339e-04
# T = 1.128058e+02
# alpha_A(T) = 7.999316e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.806296e-02
# f_H = 9.249617e-01
# prefactor_1 = 3.951736e-03
# curr_delNL0 = -1.253310e-06
# growth_factor_zp = 4.755779e-02
# input ionization = 1.105879e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 110.010124 0.017499132
# ----- DM21CM -----
# z 26.057610313536617
# [4.95922134e-10 7.91740409e-12 4.01695728e-10 5.67180039e-10
#  5.04012285e-11 3.23592850e-06]
# 4.9592214e-10
# 7.9174054e-12
# 4.0169582e-10
# 5.6718014e-10
# -----------------
# i_z=37/189 z=26.06 bath.toteng=0.000e+00 eV/Bavg
# dt 58910202736190.53 61075580157545.914
# before 110.010124 0.017499132
# input_heating 1.3056003e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.652435e-01
# zp = 2.552447e+01
# dt_dzp = -2.261747e+14
# dadia_dzp * dzp = -2.200193e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -4.835442e-01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.305600e-07
# dxion_source = 0.000000e+00
# dxion_sink = 5.294846e-04
# T = 1.100101e+02
# alpha_A(T) = 8.124264e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.749913e-02
# f_H = 9.249617e-01
# prefactor_1 = 3.835517e-03
# curr_delNL0 = -1.240885e-06
# growth_factor_zp = 4.803397e-02
# input ionization = 1.112471e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 107.32641 0.016969647
# ----- DM21CM -----
# z 25.789713181719424
# [4.91292650e-10 7.84091058e-12 3.97979321e-10 5.62086494e-10
#  4.99328146e-11 3.20384458e-06]
# 4.9129256e-10
# 7.84091e-12
# 3.979792e-10
# 5.620866e-10
# -----------------
# i_z=38/189 z=25.79 bath.toteng=0.000e+00 eV/Bavg
# dt 59798035404496.875 61995368947100.52
# before 107.32641 0.016969647
# input_heating 1.3133719e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.626190e-01
# zp = 2.526185e+01
# dt_dzp = -2.318711e+14
# dadia_dzp * dzp = -2.146532e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -4.337212e-01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.313372e-07
# dxion_source = 0.000000e+00
# dxion_sink = 4.980894e-04
# T = 1.073264e+02
# alpha_A(T) = 8.249081e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.696965e-02
# f_H = 9.249617e-01
# prefactor_1 = 3.722715e-03
# curr_delNL0 = -1.228584e-06
# growth_factor_zp = 4.851491e-02
# input ionization = 1.118683e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 104.746124 0.016471554
# ----- DM21CM -----
# z 25.524468496751904
# [4.86709076e-10 7.76517557e-12 3.94299726e-10 5.57043405e-10
#  4.94690501e-11 3.17207860e-06]
# 4.8670895e-10
# 7.765173e-12
# 3.942996e-10
# 5.570432e-10
# -----------------
# i_z=39/189 z=25.52 bath.toteng=0.000e+00 eV/Bavg
# dt 60699223846501.086 62906050916956.56
# before 104.746124 0.016471554
# input_heating 1.320719e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.600193e-01
# zp = 2.500183e+01
# dt_dzp = -2.377110e+14
# dadia_dzp * dzp = -2.094931e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -3.893086e-01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.320719e-07
# dxion_source = 0.000000e+00
# dxion_sink = 4.693212e-04
# T = 1.047461e+02
# alpha_A(T) = 8.373881e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.647156e-02
# f_H = 9.249617e-01
# prefactor_1 = 3.613230e-03
# curr_delNL0 = -1.216405e-06
# growth_factor_zp = 4.900066e-02
# input ionization = 1.124526e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 102.26188 0.016002236
# ----- DM21CM -----
# z 25.261849996784065
# [4.82170815e-10 7.69019043e-12 3.90656517e-10 5.52050137e-10
#  4.90098659e-11 3.14062707e-06]
# 4.8217086e-10
# 7.6901905e-12
# 3.9065648e-10
# 5.520502e-10
# -----------------
# i_z=40/189 z=25.26 bath.toteng=0.000e+00 eV/Bavg
# dt 61613968726102.695 63807716233645.72
# before 102.26188 0.016002236
# input_heating 1.3276522e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.574425e-01
# zp = 2.474439e+01
# dt_dzp = -2.436979e+14
# dadia_dzp * dzp = -2.045227e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -3.496405e-01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.327652e-07
# dxion_source = 0.000000e+00
# dxion_sink = 4.428989e-04
# T = 1.022619e+02
# alpha_A(T) = 8.498770e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.600223e-02
# f_H = 9.249617e-01
# prefactor_1 = 3.506966e-03
# curr_delNL0 = -1.204347e-06
# growth_factor_zp = 4.949127e-02
# input ionization = 1.130009e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 99.867035 0.015559333
# ----- DM21CM -----
# z 25.00183167998422
# [4.77677443e-10 7.61594653e-12 3.87049356e-10 5.47106348e-10
#  4.85552300e-11 3.10948650e-06]
# 4.776775e-10
# 7.615949e-12
# 3.8704936e-10
# 5.471065e-10
# -----------------
# i_z=41/189 z=25.00 bath.toteng=0.000e+00 eV/Bavg
# dt 62542473714768.94 64700454170961.71
# before 99.867035 0.015559333
# input_heating 1.3341834e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.548962e-01
# zp = 2.448949e+01
# dt_dzp = -2.498357e+14
# dadia_dzp * dzp = -1.997350e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -3.141574e-01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.334184e-07
# dxion_source = 0.000000e+00
# dxion_sink = 4.185928e-04
# T = 9.986703e+01
# alpha_A(T) = 8.623843e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.555934e-02
# f_H = 9.249617e-01
# prefactor_1 = 3.403826e-03
# curr_delNL0 = -1.192408e-06
# growth_factor_zp = 4.998678e-02
# input ionization = 1.135141e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 97.555534 0.015140742
# ----- DM21CM -----
# z 24.744387801964574
# [4.73228619e-10 7.54243856e-12 3.83477987e-10 5.42211613e-10
#  4.81051000e-11 3.07865446e-06]
# 4.732287e-10
# 7.542439e-12
# 3.8347803e-10
# 5.4221166e-10
# -----------------
# i_z=42/189 z=24.74 bath.toteng=0.000e+00 eV/Bavg
# dt 63484945536303.76 65584353118799.33
# before 97.555534 0.015140742
# input_heating 1.3403225e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.523708e-01
# zp = 2.423712e+01
# dt_dzp = -2.561280e+14
# dadia_dzp * dzp = -1.951107e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -2.823543e-01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.340322e-07
# dxion_source = 0.000000e+00
# dxion_sink = 3.961736e-04
# T = 9.755552e+01
# alpha_A(T) = 8.749195e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.514074e-02
# f_H = 9.249617e-01
# prefactor_1 = 3.303720e-03
# curr_delNL0 = -1.180588e-06
# growth_factor_zp = 5.048724e-02
# input ionization = 1.139933e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 95.32205 0.014744566
# ----- DM21CM -----
# z 24.48949287323225
# [4.68823791e-10 7.46965853e-12 3.79941900e-10 5.37365210e-10
#  4.76594227e-11 3.04812782e-06]
# 4.688238e-10
# 7.46966e-12
# 3.79942e-10
# 5.373653e-10
# -----------------
# i_z=43/189 z=24.49 bath.toteng=0.000e+00 eV/Bavg
# dt 64441594012269.28 66459500591905.87
# before 95.32205 0.014744566
# input_heating 1.3460794e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -2.498722e-01
# zp = 2.398725e+01
# dt_dzp = -2.625787e+14
# dadia_dzp * dzp = -1.906439e+00
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = -2.538133e-01
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 1.346079e-07
# dxion_source = 0.000000e+00
# dxion_sink = 3.754639e-04
# T = 9.532206e+01
# alpha_A(T) = 8.874906e-12
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 1.474457e-02
# f_H = 9.249617e-01
# prefactor_1 = 3.206558e-03
# curr_delNL0 = -1.168886e-06
# growth_factor_zp = 5.099271e-02
# input ionization = 1.144392e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 93.16182 0.014369103
# ----- DM21CM -----
# z 24.237121656665597
# [4.64462620e-10 7.39759849e-12 3.76440839e-10 5.32566841e-10
#  4.72181610e-11 3.01790344e-06]
# 4.6446255e-10
# 7.397597e-12
# 3.7644082e-10
# 5.325668e-10
# -----------------
# i_z=44/189 z=24.24 bath.toteng=0.000e+00 eV/Bavg
# dt 65412632108044.16 67325983238546.02
# before 93.16182 0.014369103
# input_heating 1.351465e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# ...
# prefactor_1 = 6.818165e-05
# curr_delNL0 = -3.239188e-07
# growth_factor_zp = 1.840111e-01
# input ionization = 2.250448e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 6.8661175 0.0038218095
# ----- DM21CM -----
# z 5.991697069763608
# [1.33534805e-10 2.06614912e-12 1.09368785e-10 1.62414624e-10
#  1.36024261e-11 8.28111289e-07]
# 1.3353484e-10
# 2.0661493e-12
# 1.093688e-10
# 1.6241462e-10
# -----------------
# i_z=173/189 z=5.99 bath.toteng=0.000e+00 eV/Bavg
# dt 448157537118852.25 460612346906398.8
# before 6.8661175 0.0038218095
# input_heating 2.8185428e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -6.853962e-02
# zp = 5.853933e+00
# dt_dzp = -6.641079e+15
# dadia_dzp * dzp = -1.373229e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 1.139891e-03
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 2.818543e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.747631e-05
# T = 6.866117e+00
# alpha_A(T) = 4.294415e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.821810e-03
# f_H = 9.249617e-01
# prefactor_1 = 6.617643e-05
# curr_delNL0 = -3.207222e-07
# growth_factor_zp = 1.858451e-01
# input ionization = 2.256710e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 6.729934 0.0038043337
# ----- DM21CM -----
# z 5.9224723463006015
# [1.32211312e-10 2.04534966e-12 1.08293582e-10 1.60897634e-10
#  1.34675834e-11 8.19768114e-07]
# 1.3221131e-10
# 2.0453496e-12
# 1.08293575e-10
# 1.6089767e-10
# -----------------
# i_z=174/189 z=5.92 bath.toteng=0.000e+00 eV/Bavg
# dt 454854340715004.25 466386447912570.75
# before 6.729934 0.0038043337
# input_heating 2.8272348e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -6.786060e-02
# zp = 5.786072e+00
# dt_dzp = -6.807644e+15
# dadia_dzp * dzp = -1.345984e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 1.102130e-03
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 2.827235e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.725697e-05
# T = 6.729934e+00
# alpha_A(T) = 4.344399e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.804334e-03
# f_H = 9.249617e-01
# prefactor_1 = 6.423019e-05
# curr_delNL0 = -3.175576e-07
# growth_factor_zp = 1.876971e-01
# input ionization = 2.262347e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 6.5964375 0.0037870773
# ----- DM21CM -----
# z 5.85393301613921
# [1.30900912e-10 2.02475576e-12 1.07229028e-10 1.59395638e-10
#  1.33340744e-11 8.11507468e-07]
# 1.3090092e-10
# 2.0247554e-12
# 1.0722902e-10
# 1.5939564e-10
# -----------------
# i_z=175/189 z=5.85 bath.toteng=0.000e+00 eV/Bavg
# dt 461649758730236.06 472103379601849.94
# before 6.5964375 0.0037870773
# input_heating 2.8351906e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -6.718874e-02
# zp = 5.718884e+00
# dt_dzp = -6.978365e+15
# dadia_dzp * dzp = -1.319286e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 1.065565e-03
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 2.835190e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.704157e-05
# T = 6.596438e+00
# alpha_A(T) = 4.394934e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.787077e-03
# f_H = 9.249617e-01
# prefactor_1 = 6.234119e-05
# curr_delNL0 = -3.144245e-07
# growth_factor_zp = 1.895674e-01
# input ionization = 2.267375e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 6.4655757 0.003770035
# ----- DM21CM -----
# z 5.7860722932071385
# [1.29603497e-10 2.00436594e-12 1.06175016e-10 1.57908520e-10
#  1.32018872e-11 8.03328655e-07]
# 1.2960348e-10
# 2.0043652e-12
# 1.0617498e-10
# 1.5790849e-10
# -----------------
# i_z=176/189 z=5.79 bath.toteng=0.000e+00 eV/Bavg
# dt 468545178767795.9 477763708007076.9
# before 6.4655757 0.003770035
# input_heating 2.8424301e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -6.652355e-02
# zp = 5.652360e+00
# dt_dzp = -7.153344e+15
# dadia_dzp * dzp = -1.293114e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 1.030157e-03
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 2.842430e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.682992e-05
# T = 6.465575e+00
# alpha_A(T) = 4.446027e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.770035e-03
# f_H = 9.249617e-01
# prefactor_1 = 6.050775e-05
# curr_delNL0 = -3.113228e-07
# growth_factor_zp = 1.914561e-01
# input ionization = 2.271811e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 6.337295 0.0037532048
# ----- DM21CM -----
# z 5.718883458620929
# [1.28318931e-10 1.98417803e-12 1.05131429e-10 1.56436132e-10
#  1.30710111e-11 7.95230806e-07]
# 1.2831894e-10
# 1.9841784e-12
# 1.0513143e-10
# 1.5643614e-10
# -----------------
# i_z=177/189 z=5.72 bath.toteng=0.000e+00 eV/Bavg
# dt 475542005016296.44 483367993556806.5
# before 6.337295 0.0037532048
# input_heating 2.8489734e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -6.586504e-02
# zp = 5.586495e+00
# dt_dzp = -7.332686e+15
# dadia_dzp * dzp = -1.267461e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 9.958737e-04
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 2.848973e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.662195e-05
# T = 6.337294e+00
# alpha_A(T) = 4.497683e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.753205e-03
# f_H = 9.249617e-01
# prefactor_1 = 5.872822e-05
# curr_delNL0 = -3.082520e-07
# growth_factor_zp = 1.933634e-01
# input ionization = 2.275673e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 6.211545 0.0037365826
# ----- DM21CM -----
# z 5.652359860020722
# [1.27047075e-10 1.96419004e-12 1.04098182e-10 1.54978313e-10
#  1.29414288e-11 7.87213136e-07]
# 1.2704708e-10
# 1.9641899e-12
# 1.04098175e-10
# 1.5497831e-10
# -----------------
# i_z=178/189 z=5.65 bath.toteng=0.000e+00 eV/Bavg
# dt 482641658309570.2 488916791130796.2
# before 6.211545 0.0037365826
# input_heating 2.8548396e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -6.521273e-02
# zp = 5.521282e+00
# dt_dzp = -7.516499e+15
# dadia_dzp * dzp = -1.242307e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 9.626757e-04
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 2.854839e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.641747e-05
# T = 6.211544e+00
# alpha_A(T) = 4.549908e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.736583e-03
# f_H = 9.249617e-01
# prefactor_1 = 5.700104e-05
# curr_delNL0 = -3.052120e-07
# growth_factor_zp = 1.952894e-01
# input ionization = 2.278976e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 6.0882773 0.0037201652
# ----- DM21CM -----
# z 5.586494910911606
# [1.25787812e-10 1.94439981e-12 1.03075169e-10 1.53534936e-10
#  1.28131298e-11 7.79274861e-07]
# 1.2578781e-10
# 1.9444e-12
# 1.03075166e-10
# 1.5353492e-10
# -----------------
# i_z=179/189 z=5.59 bath.toteng=0.000e+00 eV/Bavg
# dt 489845576179693.25 494410650114944.44
# before 6.0882773 0.0037201652
# input_heating 2.8600473e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -6.456709e-02
# zp = 5.456715e+00
# dt_dzp = -7.704892e+15
# dadia_dzp * dzp = -1.217654e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 9.305396e-04
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 2.860048e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.621653e-05
# T = 6.088276e+00
# alpha_A(T) = 4.602707e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.720166e-03
# f_H = 9.249617e-01
# prefactor_1 = 5.532465e-05
# curr_delNL0 = -3.022022e-07
# growth_factor_zp = 1.972343e-01
# input ionization = 2.281736e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 5.967443 0.0037039488
# ----- DM21CM -----
# z 5.521282090011491
# [1.24541025e-10 1.92480552e-12 1.02062273e-10 1.52105853e-10
#  1.26861020e-11 7.71415199e-07]
# 1.2454102e-10
# 1.9248054e-12
# 1.0206227e-10
# 1.5210581e-10
# -----------------
# i_z=180/189 z=5.52 bath.toteng=0.000e+00 eV/Bavg
# dt 497155212901981.44 499926452661765.7
# before 5.967443 0.0037039488
# input_heating 2.8650408e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -6.392813e-02
# zp = 5.392787e+00
# dt_dzp = -7.897979e+15
# dadia_dzp * dzp = -1.193493e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 8.994349e-04
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 2.865041e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.601907e-05
# T = 5.967442e+00
# alpha_A(T) = 4.656088e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.703949e-03
# f_H = 9.249617e-01
# prefactor_1 = 5.369755e-05
# curr_delNL0 = -2.992226e-07
# growth_factor_zp = 1.991984e-01
# input ionization = 2.284311e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 5.848992 0.0036879296
# ----- DM21CM -----
# z 5.456714940605437
# [1.23306247e-10 1.90540202e-12 1.01059100e-10 1.50690277e-10
#  1.25602963e-11 7.63632582e-07]
# 1.2330624e-10
# 1.905402e-12
# 1.010591e-10
# 1.5069031e-10
# -----------------
# i_z=181/189 z=5.46 bath.toteng=0.000e+00 eV/Bavg
# dt 504572039532090.56 510034542352722.4
# before 5.848992 0.0036879296
# input_heating 2.895028e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -6.329489e-02
# zp = 5.329492e+00
# dt_dzp = -8.095874e+15
# dadia_dzp * dzp = -1.169798e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 8.693192e-04
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 2.895028e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.582479e-05
# T = 5.848992e+00
# alpha_A(T) = 4.710056e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.687930e-03
# f_H = 9.249617e-01
# prefactor_1 = 5.211831e-05
# curr_delNL0 = -2.962727e-07
# growth_factor_zp = 2.011817e-01
# input ionization = 2.307002e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 5.732882 0.003672105
# ----- DM21CM -----
# z 5.392787069906373
# [1.22063297e-10 1.88598457e-12 1.00047022e-10 1.49249790e-10
#  1.24336019e-11 7.55885832e-07]
# 1.2206332e-10
# 1.8859846e-12
# 1.0004704e-10
# 1.4924981e-10
# -----------------
# i_z=182/189 z=5.39 bath.toteng=0.000e+00 eV/Bavg
# dt 512097543934177.8 520042551947729.06
# before 5.732882 0.003672105
# input_heating 2.923628e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -6.266832e-02
# zp = 5.266824e+00
# dt_dzp = -8.298696e+15
# dadia_dzp * dzp = -1.146578e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 8.401768e-04
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 2.923628e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.563386e-05
# T = 5.732882e+00
# alpha_A(T) = 4.764617e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.672105e-03
# f_H = 9.249617e-01
# prefactor_1 = 5.058552e-05
# curr_delNL0 = -2.933524e-07
# growth_factor_zp = 2.031845e-01
# input ionization = 2.328551e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 5.619065 0.003656472
# ----- DM21CM -----
# z 5.329492148422152
# [1.20832673e-10 1.86675958e-12 9.90449765e-11 1.47823598e-10
#  1.23081628e-11 7.48215693e-07]
# 1.2083268e-10
# 1.866759e-12
# 9.904496e-11
# 1.4782356e-10
# -----------------
# i_z=183/189 z=5.33 bath.toteng=0.000e+00 eV/Bavg
# dt 519733230800262.9 529951472338824.75
# before 5.619065 0.003656472
# input_heating 2.9508743e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -6.204748e-02
# zp = 5.204776e+00
# dt_dzp = -8.506564e+15
# dadia_dzp * dzp = -1.123808e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 8.119671e-04
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 2.950875e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.544598e-05
# T = 5.619065e+00
# alpha_A(T) = 4.819777e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.656472e-03
# f_H = 9.249617e-01
# prefactor_1 = 4.909781e-05
# curr_delNL0 = -2.904612e-07
# growth_factor_zp = 2.052069e-01
# input ionization = 2.348988e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 5.5074973 0.0036410252
# ----- DM21CM -----
# z 5.266823909328863
# [1.19614229e-10 1.84772487e-12 9.80528456e-11 1.46411496e-10
#  1.21839672e-11 7.40621641e-07]
# 1.1961424e-10
# 1.847725e-12
# 9.805287e-11
# 1.4641151e-10
# -----------------
# i_z=184/189 z=5.27 bath.toteng=0.000e+00 eV/Bavg
# dt 527480621659631.6 539762284607236.44
# before 5.5074973 0.0036410252
# input_heating 2.9768034e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -6.143379e-02
# zp = 5.143342e+00
# dt_dzp = -8.719606e+15
# dadia_dzp * dzp = -1.101506e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 7.846810e-04
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 2.976803e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.526147e-05
# T = 5.507496e+00
# alpha_A(T) = 4.875542e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.641026e-03
# f_H = 9.249617e-01
# prefactor_1 = 4.765385e-05
# curr_delNL0 = -2.875990e-07
# growth_factor_zp = 2.072491e-01
# input ionization = 2.368340e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 5.398132 0.0036257647
# ----- DM21CM -----
# z 5.204776147850359
# [1.18407857e-10 1.82887879e-12 9.70705342e-11 1.45013402e-10
#  1.20610002e-11 7.33102632e-07]
# 1.184079e-10
# 1.8288793e-12
# 9.707058e-11
# 1.4501342e-10
# -----------------
# i_z=185/189 z=5.20 bath.toteng=0.000e+00 eV/Bavg
# dt 535341254878156.3 549475960120515.25
# before 5.398132 0.0036257647
# input_heating 3.0014468e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -6.082487e-02
# zp = 5.082518e+00
# dt_dzp = -8.937943e+15
# dadia_dzp * dzp = -1.079621e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 7.582618e-04
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 3.001447e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.507966e-05
# T = 5.398131e+00
# alpha_A(T) = 4.931921e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.625764e-03
# f_H = 9.249617e-01
# prefactor_1 = 4.625236e-05
# curr_delNL0 = -2.847655e-07
# growth_factor_zp = 2.093114e-01
# input ionization = 2.386636e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 5.290927 0.0036106852
# ----- DM21CM -----
# z 5.14334272064392
# [1.17213408e-10 1.81021885e-12 9.60979358e-11 1.43629111e-10
#  1.19392501e-11 7.25658057e-07]
# 1.1721342e-10
# 1.810219e-12
# 9.609794e-11
# 1.4362912e-10
# -----------------
# i_z=186/189 z=5.14 bath.toteng=0.000e+00 eV/Bavg
# dt 543316685646789.7 559093460628712.06
# before 5.290927 0.0036106852
# input_heating 3.0248398e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -6.022310e-02
# zp = 5.022295e+00
# dt_dzp = -9.161709e+15
# dadia_dzp * dzp = -1.058188e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 7.327132e-04
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 3.024840e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.490110e-05
# T = 5.290927e+00
# alpha_A(T) = 4.988917e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.610685e-03
# f_H = 9.249617e-01
# prefactor_1 = 4.489208e-05
# curr_delNL0 = -2.819602e-07
# growth_factor_zp = 2.113938e-01
# input ionization = 2.403904e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 5.1858416 0.003595784
# ----- DM21CM -----
# z 5.082517545192
# [1.16030809e-10 1.79174422e-12 9.51349975e-11 1.42258572e-10
#  1.18187061e-11 7.18287349e-07]
# 1.1603078e-10
# 1.7917438e-12
# 9.513499e-11
# 1.4225852e-10
# -----------------
# i_z=187/189 z=5.08 bath.toteng=0.000e+00 eV/Bavg
# dt 551408485958770.9 568615738359600.0
# before 5.1858416 0.003595784
# input_heating 3.0470122e-07
# This is commented out: dspec_dzp = - dxe_dzp * T / (1+x_e); need to put it back in
# box_ct = 0
# dzp = -5.962658e-02
# zp = 4.962668e+00
# dt_dzp = -9.391035e+15
# dadia_dzp * dzp = -1.037167e-01
# dspec_dzp * dzp = 0.000000e+00
# dcomp_dzp * dzp = 7.079867e-04
# dxheat_dzp * dzp = 0.000000e+00
# input heating = 3.047012e-07
# dxion_source = 0.000000e+00
# dxion_sink = 1.472527e-05
# T = 5.185842e+00
# alpha_A(T) = 5.046539e-11
# global_params.CLUMPING_FACTOR = 1.000000e+00
# x_e = 3.595783e-03
# f_H = 9.249617e-01
# prefactor_1 = 4.357181e-05
# curr_delNL0 = -2.791832e-07
# growth_factor_zp = 2.134966e-01
# input ionization = 2.420171e-12
#
# N_b0 = 2.055340e-07
# f_H = 9.249617e-01
#
# after 5.082833 0.003581058
# ----- DM21CM -----
# z 5.0222945992
# [1.14859909e-10 1.77345207e-12 9.41815703e-11 1.40901572e-10
#  1.16993550e-11 7.10989508e-07]
# 1.1485993e-10
# 1.7734523e-12
# 9.418157e-11
# 1.4090157e-10
# -----------------
# i_z=188/189 z=5.02 bath.toteng=0.000e+00 eV/Bavg
# xray: 0.0079 +/- 0.0013 s
# bath+dm: 0.0268 +/- 0.0020 s
# 21cmFAST: 0.5160 +/- 0.0093 s
# prep_next: 0.0419 +/- 0.0112 s

# %%
run_name = 'dhc_test'
soln = np.load(f"../run_info/{run_name}_records.npy", allow_pickle=True).item()
np.array([soln['f_ion'][2], soln['f_exc'][2], soln['f_heat'][2]]) / np.array([f_dh[0] + f_dh[1], f_dh[2], f_dh[3]])
# Out:
# array([0.99999976, 0.9999999 , 0.99999986])

# %% [markdown]
# ## A. HED pipeline

# %%
# .npy
data_dir = f"{os.environ['DM21CM_DATA_DIR']}/tf/zf01/phot"
hed_tfgv = np.load(f'{data_dir}/hed_tf_rxneo.npy')
hed_tfgv[8, 3, 6, 429]
# Out:
# array([11.0582994 ,  8.78602481,  3.48876916, -0.0763134 ])

# %%
# dm21cm tf
tf = np.load(f"{os.environ['DM21CM_DATA_DIR']}/tf/zf01/phot/hed_tf_rxneo.npy")
tf[8, 3, 6, 429]
# Out:
# array([11.0582994 ,  8.78602481,  3.48876916, -0.0763134 ])

# %%
# dhtf
dhtf = pickle.load(open(f"{os.environ['DH_DATA_DIR']}/../DHdata_v1_1_zf01/highengdep_interp.raw", 'rb'))
dhtf.grid_vals[0][3, 0, 8, 429] * (abscs['dlnz'] / phys.hubble(abscs['rs'][-2]))
# Out:
# array([11.0582994 ,  8.78602481,  3.48876916, -0.0763134 ])

# %%
dhtf.get_val(0.01, 0.9, abscs['rs'][-2])[429] * (abscs['dlnz'] / phys.hubble(abscs['rs'][-2]))
# Out:
# array([11.0582994 ,  8.78602481,  3.48876916, -0.0763134 ])

# %% [markdown]
# correct!!
