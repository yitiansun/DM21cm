# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc_file("../../plotting/matplotlibrc")

# %%
start_rs = [3000, 2750, 2500, 2000]
f_step = 0.00017783
sigmas = np.array([43.01595104, 42.99957697, 43.06362734, 41.76884363])
limits = np.sqrt(stats.chi2.ppf(.9, df=1)) * f_step * sigmas

fig, ax = plt.subplots()
ax.plot(start_rs, limits, 's-')
ax.set(xlabel='Starting redshift', ylabel=r'Limit on $f$',)
# Out:
# [Text(0.5, 0, 'Starting redshift'), Text(0, 0.5, 'Limit on $f$')]
