# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import sys, os

sys.path.append(os.environ['DH_DIR'])
from darkhistory.spec.spectrum import Spectrum
import darkhistory.physics as phys

sys.path.append(os.environ['IH_DIR'])
from maketf.abscissa import abscs

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc_file('../matplotlibrc')

# %%
from util import plot_val

# %%
DIR = '/zfs/yitians/ionhist/ionhist/maketf/tfdata/array/nhd_test'

# %%
hep_tf = np.load(DIR+'/hep_tf.npy')

# %%
hep_tf.shape
# Out:
# (5, 5, 5, 500, 500)

# %%
fig, axs = plt.subplots(1, 5, figsize=(25, 5))

extent = np.log10((abscs['photeng'][0],abscs['photeng'][-1], abscs['photeng'][0], abscs['photeng'][-1]))

for i in range(5):
    axs[i].imshow(plot_val(hep_tf[i,2,4]), vmin=-55, vmax=10, extent=extent, cmap='plasma')
    axs[i].set(xlabel='$\log_{10}E_{out}$', ylabel='$\log_{10}E_{in}$')
axs[0].set(title='highengphot');
