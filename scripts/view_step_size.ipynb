# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np

import matplotlib.pyplot as plt

# %%
from step_size import pbhacc_f

# %%
m_s = np.logspace(0, 4, 100)

# %%
mn_s = ['PRc23', 'PRc23dm', 'PRc23dp', 'PRc50', 'PRc10']
color_s = ['k', 'C0', 'C0', 'C1', 'C1']
ls_s = ['-', '-', '--', '-', '--']
for i, mn in enumerate(mn_s):
    plt.plot(m_s, pbhacc_f(m_s, mn), label=mn, color=color_s[i], ls=ls_s[i])
plt.loglog()
# Out:
# []
