# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc_file("../matplotlibrc")

from step_size import pbhacc_f

# %%
pbhacc_f(100, 'PRc23dp')
# Out:
# 1.584893192461114e-05

# %%
m_s = np.logspace(0, 4, 100)

mn_s = ['PRc23', 'PRc23dm', 'PRc23dp', 'PRc29', 'PRc14']
color_s = ['k', 'C0', 'C0', 'C1', 'C1']
ls_s = ['-', '-', '--', '-', '--']

fig, ax = plt.subplots(figsize=(6, 4))
for i, mn in enumerate(mn_s):
    ax.plot(m_s, pbhacc_f(m_s, mn), label=mn, color=color_s[i], ls=ls_s[i])

ax.set(xscale='log', yscale='log')
ax.legend(frameon=False)

# %%
10**0.25
# Out:
# 1.7782794100389228
